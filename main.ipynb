# %%
import pandas as pd

class Automovil:
  def __init__(self, mpg, cilindros, desplazamiento, caballos_de_fuerza,
               peso, aceleracion, anio, origen, nombre):
    self.__mpg = mpg,
    self.__cilindros = cilindros,
    self.__desplazamiento = desplazamiento
    self.__caballos_de_fuerza = caballos_de_fuerza,
    self.__peso = peso
    self.__aceleracion = aceleracion
    self.__anio = anio
    self.__origen = origen
    self.__nombre = nombre
    
  def __str__(self):
    texto = "modelo: {0}, anio-fabricacion: {1}, peso: {2}, origen: {3}"
    return texto.format(self.__nombre,self.__anio,self.__peso,self.__origen)

datos = pd.read_csv('auto-mpg.csv')

autos = [(Automovil(row["mpg"], row["cylinders"], row["displacement"], row["horsepower"],
                    row["weight"], row["acceleration"], row["model year"], row.origin, row["car name"])) for index, row in datos.iterrows() ]

for item in autos :
  print(item)
# Out:
# modelo: chevrolet chevelle malibu, anio-fabricacion: 70, peso: 3504, origen: 1
# modelo: buick skylark 320, anio-fabricacion: 70, peso: 3693, origen: 1
# modelo: plymouth satellite, anio-fabricacion: 70, peso: 3436, origen: 1
# modelo: amc rebel sst, anio-fabricacion: 70, peso: 3433, origen: 1
# modelo: ford torino, anio-fabricacion: 70, peso: 3449, origen: 1
# modelo: ford galaxie 500, anio-fabricacion: 70, peso: 4341, origen: 1
# modelo: chevrolet impala, anio-fabricacion: 70, peso: 4354, origen: 1
# modelo: plymouth fury iii, anio-fabricacion: 70, peso: 4312, origen: 1
# modelo: pontiac catalina, anio-fabricacion: 70, peso: 4425, origen: 1
# modelo: amc ambassador dpl, anio-fabricacion: 70, peso: 3850, origen: 1
# modelo: citroen ds-21 pallas, anio-fabricacion: 70, peso: 3090, origen: 2
# modelo: chevrolet chevelle concours (sw), anio-fabricacion: 70, peso: 4142, origen: 1
# modelo: ford torino (sw), anio-fabricacion: 70, peso: 4034, origen: 1
# modelo: plymouth satellite (sw), anio-fabricacion: 70, peso: 4166, origen: 1
# modelo: amc rebel sst (sw), anio-fabricacion: 70, peso: 3850, origen: 1
# modelo: dodge challenger se, anio-fabricacion: 70, peso: 3563, origen: 1
# modelo: plymouth 'cuda 340, anio-fabricacion: 70, peso: 3609, origen: 1
# modelo: ford mustang boss 302, anio-fabricacion: 70, peso: 3353, origen: 1
# modelo: chevrolet monte carlo, anio-fabricacion: 70, peso: 3761, origen: 1
# modelo: buick estate wagon (sw), anio-fabricacion: 70, peso: 3086, origen: 1
# modelo: toyota corona mark ii, anio-fabricacion: 70, peso: 2372, origen: 3
# modelo: plymouth duster, anio-fabricacion: 70, peso: 2833, origen: 1
# modelo: amc hornet, anio-fabricacion: 70, peso: 2774, origen: 1
# modelo: ford maverick, anio-fabricacion: 70, peso: 2587, origen: 1
# modelo: datsun pl510, anio-fabricacion: 70, peso: 2130, origen: 3
# modelo: volkswagen 1131 deluxe sedan, anio-fabricacion: 70, peso: 1835, origen: 2
# modelo: peugeot 504, anio-fabricacion: 70, peso: 2672, origen: 2
# modelo: audi 100 ls, anio-fabricacion: 70, peso: 2430, origen: 2
# modelo: saab 99e, anio-fabricacion: 70, peso: 2375, origen: 2
# modelo: bmw 2002, anio-fabricacion: 70, peso: 2234, origen: 2
# modelo: amc gremlin, anio-fabricacion: 70, peso: 2648, origen: 1
# modelo: ford f250, anio-fabricacion: 70, peso: 4615, origen: 1
# modelo: chevy c20, anio-fabricacion: 70, peso: 4376, origen: 1
# modelo: dodge d200, anio-fabricacion: 70, peso: 4382, origen: 1
# modelo: hi 1200d, anio-fabricacion: 70, peso: 4732, origen: 1
# modelo: datsun pl510, anio-fabricacion: 71, peso: 2130, origen: 3
# modelo: chevrolet vega 2300, anio-fabricacion: 71, peso: 2264, origen: 1
# modelo: toyota corona, anio-fabricacion: 71, peso: 2228, origen: 3
# modelo: ford pinto, anio-fabricacion: 71, peso: 2046, origen: 1
# modelo: volkswagen super beetle 117, anio-fabricacion: 71, peso: 1978, origen: 2
# modelo: amc gremlin, anio-fabricacion: 71, peso: 2634, origen: 1
# modelo: plymouth satellite custom, anio-fabricacion: 71, peso: 3439, origen: 1
# modelo: chevrolet chevelle malibu, anio-fabricacion: 71, peso: 3329, origen: 1
# modelo: ford torino 500, anio-fabricacion: 71, peso: 3302, origen: 1
# modelo: amc matador, anio-fabricacion: 71, peso: 3288, origen: 1
# modelo: chevrolet impala, anio-fabricacion: 71, peso: 4209, origen: 1
# modelo: pontiac catalina brougham, anio-fabricacion: 71, peso: 4464, origen: 1
# modelo: ford galaxie 500, anio-fabricacion: 71, peso: 4154, origen: 1
# modelo: plymouth fury iii, anio-fabricacion: 71, peso: 4096, origen: 1
# modelo: dodge monaco (sw), anio-fabricacion: 71, peso: 4955, origen: 1
# modelo: ford country squire (sw), anio-fabricacion: 71, peso: 4746, origen: 1
# modelo: pontiac safari (sw), anio-fabricacion: 71, peso: 5140, origen: 1
# modelo: amc hornet sportabout (sw), anio-fabricacion: 71, peso: 2962, origen: 1
# modelo: chevrolet vega (sw), anio-fabricacion: 71, peso: 2408, origen: 1
# modelo: pontiac firebird, anio-fabricacion: 71, peso: 3282, origen: 1
# modelo: ford mustang, anio-fabricacion: 71, peso: 3139, origen: 1
# modelo: mercury capri 2000, anio-fabricacion: 71, peso: 2220, origen: 1
# modelo: opel 1900, anio-fabricacion: 71, peso: 2123, origen: 2
# modelo: peugeot 304, anio-fabricacion: 71, peso: 2074, origen: 2
# modelo: fiat 124b, anio-fabricacion: 71, peso: 2065, origen: 2
# modelo: toyota corolla 1200, anio-fabricacion: 71, peso: 1773, origen: 3
# modelo: datsun 1200, anio-fabricacion: 71, peso: 1613, origen: 3
# modelo: volkswagen model 111, anio-fabricacion: 71, peso: 1834, origen: 2
# modelo: plymouth cricket, anio-fabricacion: 71, peso: 1955, origen: 1
# modelo: toyota corona hardtop, anio-fabricacion: 72, peso: 2278, origen: 3
# modelo: dodge colt hardtop, anio-fabricacion: 72, peso: 2126, origen: 1
# modelo: volkswagen type 3, anio-fabricacion: 72, peso: 2254, origen: 2
# modelo: chevrolet vega, anio-fabricacion: 72, peso: 2408, origen: 1
# modelo: ford pinto runabout, anio-fabricacion: 72, peso: 2226, origen: 1
# modelo: chevrolet impala, anio-fabricacion: 72, peso: 4274, origen: 1
# modelo: pontiac catalina, anio-fabricacion: 72, peso: 4385, origen: 1
# modelo: plymouth fury iii, anio-fabricacion: 72, peso: 4135, origen: 1
# modelo: ford galaxie 500, anio-fabricacion: 72, peso: 4129, origen: 1
# modelo: amc ambassador sst, anio-fabricacion: 72, peso: 3672, origen: 1
# modelo: mercury marquis, anio-fabricacion: 72, peso: 4633, origen: 1
# modelo: buick lesabre custom, anio-fabricacion: 72, peso: 4502, origen: 1
# modelo: oldsmobile delta 88 royale, anio-fabricacion: 72, peso: 4456, origen: 1
# modelo: chrysler newport royal, anio-fabricacion: 72, peso: 4422, origen: 1
# modelo: mazda rx2 coupe, anio-fabricacion: 72, peso: 2330, origen: 3
# modelo: amc matador (sw), anio-fabricacion: 72, peso: 3892, origen: 1
# modelo: chevrolet chevelle concours (sw), anio-fabricacion: 72, peso: 4098, origen: 1
# modelo: ford gran torino (sw), anio-fabricacion: 72, peso: 4294, origen: 1
# modelo: plymouth satellite custom (sw), anio-fabricacion: 72, peso: 4077, origen: 1
# modelo: volvo 145e (sw), anio-fabricacion: 72, peso: 2933, origen: 2
# modelo: volkswagen 411 (sw), anio-fabricacion: 72, peso: 2511, origen: 2
# modelo: peugeot 504 (sw), anio-fabricacion: 72, peso: 2979, origen: 2
# modelo: renault 12 (sw), anio-fabricacion: 72, peso: 2189, origen: 2
# modelo: ford pinto (sw), anio-fabricacion: 72, peso: 2395, origen: 1
# modelo: datsun 510 (sw), anio-fabricacion: 72, peso: 2288, origen: 3
# modelo: toyouta corona mark ii (sw), anio-fabricacion: 72, peso: 2506, origen: 3
# modelo: dodge colt (sw), anio-fabricacion: 72, peso: 2164, origen: 1
# modelo: toyota corolla 1600 (sw), anio-fabricacion: 72, peso: 2100, origen: 3
# modelo: buick century 350, anio-fabricacion: 73, peso: 4100, origen: 1
# modelo: amc matador, anio-fabricacion: 73, peso: 3672, origen: 1
# modelo: chevrolet malibu, anio-fabricacion: 73, peso: 3988, origen: 1
# modelo: ford gran torino, anio-fabricacion: 73, peso: 4042, origen: 1
# modelo: dodge coronet custom, anio-fabricacion: 73, peso: 3777, origen: 1
# modelo: mercury marquis brougham, anio-fabricacion: 73, peso: 4952, origen: 1
# modelo: chevrolet caprice classic, anio-fabricacion: 73, peso: 4464, origen: 1
# modelo: ford ltd, anio-fabricacion: 73, peso: 4363, origen: 1
# modelo: plymouth fury gran sedan, anio-fabricacion: 73, peso: 4237, origen: 1
# modelo: chrysler new yorker brougham, anio-fabricacion: 73, peso: 4735, origen: 1
# modelo: buick electra 225 custom, anio-fabricacion: 73, peso: 4951, origen: 1
# modelo: amc ambassador brougham, anio-fabricacion: 73, peso: 3821, origen: 1
# modelo: plymouth valiant, anio-fabricacion: 73, peso: 3121, origen: 1
# modelo: chevrolet nova custom, anio-fabricacion: 73, peso: 3278, origen: 1
# modelo: amc hornet, anio-fabricacion: 73, peso: 2945, origen: 1
# modelo: ford maverick, anio-fabricacion: 73, peso: 3021, origen: 1
# modelo: plymouth duster, anio-fabricacion: 73, peso: 2904, origen: 1
# modelo: volkswagen super beetle, anio-fabricacion: 73, peso: 1950, origen: 2
# modelo: chevrolet impala, anio-fabricacion: 73, peso: 4997, origen: 1
# modelo: ford country, anio-fabricacion: 73, peso: 4906, origen: 1
# modelo: plymouth custom suburb, anio-fabricacion: 73, peso: 4654, origen: 1
# modelo: oldsmobile vista cruiser, anio-fabricacion: 73, peso: 4499, origen: 1
# modelo: amc gremlin, anio-fabricacion: 73, peso: 2789, origen: 1
# modelo: toyota carina, anio-fabricacion: 73, peso: 2279, origen: 3
# modelo: chevrolet vega, anio-fabricacion: 73, peso: 2401, origen: 1
# modelo: datsun 610, anio-fabricacion: 73, peso: 2379, origen: 3
# modelo: maxda rx3, anio-fabricacion: 73, peso: 2124, origen: 3
# modelo: ford pinto, anio-fabricacion: 73, peso: 2310, origen: 1
# modelo: mercury capri v6, anio-fabricacion: 73, peso: 2472, origen: 1
# modelo: fiat 124 sport coupe, anio-fabricacion: 73, peso: 2265, origen: 2
# modelo: chevrolet monte carlo s, anio-fabricacion: 73, peso: 4082, origen: 1
# modelo: pontiac grand prix, anio-fabricacion: 73, peso: 4278, origen: 1
# modelo: fiat 128, anio-fabricacion: 73, peso: 1867, origen: 2
# modelo: opel manta, anio-fabricacion: 73, peso: 2158, origen: 2
# modelo: audi 100ls, anio-fabricacion: 73, peso: 2582, origen: 2
# modelo: volvo 144ea, anio-fabricacion: 73, peso: 2868, origen: 2
# modelo: dodge dart custom, anio-fabricacion: 73, peso: 3399, origen: 1
# modelo: saab 99le, anio-fabricacion: 73, peso: 2660, origen: 2
# modelo: toyota mark ii, anio-fabricacion: 73, peso: 2807, origen: 3
# modelo: oldsmobile omega, anio-fabricacion: 73, peso: 3664, origen: 1
# modelo: plymouth duster, anio-fabricacion: 74, peso: 3102, origen: 1
# modelo: ford maverick, anio-fabricacion: 74, peso: 2875, origen: 1
# modelo: amc hornet, anio-fabricacion: 74, peso: 2901, origen: 1
# modelo: chevrolet nova, anio-fabricacion: 74, peso: 3336, origen: 1
# modelo: datsun b210, anio-fabricacion: 74, peso: 1950, origen: 3
# modelo: ford pinto, anio-fabricacion: 74, peso: 2451, origen: 1
# modelo: toyota corolla 1200, anio-fabricacion: 74, peso: 1836, origen: 3
# modelo: chevrolet vega, anio-fabricacion: 74, peso: 2542, origen: 1
# modelo: chevrolet chevelle malibu classic, anio-fabricacion: 74, peso: 3781, origen: 1
# modelo: amc matador, anio-fabricacion: 74, peso: 3632, origen: 1
# modelo: plymouth satellite sebring, anio-fabricacion: 74, peso: 3613, origen: 1
# modelo: ford gran torino, anio-fabricacion: 74, peso: 4141, origen: 1
# modelo: buick century luxus (sw), anio-fabricacion: 74, peso: 4699, origen: 1
# modelo: dodge coronet custom (sw), anio-fabricacion: 74, peso: 4457, origen: 1
# modelo: ford gran torino (sw), anio-fabricacion: 74, peso: 4638, origen: 1
# modelo: amc matador (sw), anio-fabricacion: 74, peso: 4257, origen: 1
# modelo: audi fox, anio-fabricacion: 74, peso: 2219, origen: 2
# modelo: volkswagen dasher, anio-fabricacion: 74, peso: 1963, origen: 2
# modelo: opel manta, anio-fabricacion: 74, peso: 2300, origen: 2
# modelo: toyota corona, anio-fabricacion: 74, peso: 1649, origen: 3
# modelo: datsun 710, anio-fabricacion: 74, peso: 2003, origen: 3
# modelo: dodge colt, anio-fabricacion: 74, peso: 2125, origen: 1
# modelo: fiat 128, anio-fabricacion: 74, peso: 2108, origen: 2
# modelo: fiat 124 tc, anio-fabricacion: 74, peso: 2246, origen: 2
# modelo: honda civic, anio-fabricacion: 74, peso: 2489, origen: 3
# modelo: subaru, anio-fabricacion: 74, peso: 2391, origen: 3
# modelo: fiat x1.9, anio-fabricacion: 74, peso: 2000, origen: 2
# modelo: plymouth valiant custom, anio-fabricacion: 75, peso: 3264, origen: 1
# modelo: chevrolet nova, anio-fabricacion: 75, peso: 3459, origen: 1
# modelo: mercury monarch, anio-fabricacion: 75, peso: 3432, origen: 1
# modelo: ford maverick, anio-fabricacion: 75, peso: 3158, origen: 1
# modelo: pontiac catalina, anio-fabricacion: 75, peso: 4668, origen: 1
# modelo: chevrolet bel air, anio-fabricacion: 75, peso: 4440, origen: 1
# modelo: plymouth grand fury, anio-fabricacion: 75, peso: 4498, origen: 1
# modelo: ford ltd, anio-fabricacion: 75, peso: 4657, origen: 1
# modelo: buick century, anio-fabricacion: 75, peso: 3907, origen: 1
# modelo: chevroelt chevelle malibu, anio-fabricacion: 75, peso: 3897, origen: 1
# modelo: amc matador, anio-fabricacion: 75, peso: 3730, origen: 1
# modelo: plymouth fury, anio-fabricacion: 75, peso: 3785, origen: 1
# modelo: buick skyhawk, anio-fabricacion: 75, peso: 3039, origen: 1
# modelo: chevrolet monza 2+2, anio-fabricacion: 75, peso: 3221, origen: 1
# modelo: ford mustang ii, anio-fabricacion: 75, peso: 3169, origen: 1
# modelo: toyota corolla, anio-fabricacion: 75, peso: 2171, origen: 3
# modelo: ford pinto, anio-fabricacion: 75, peso: 2639, origen: 1
# modelo: amc gremlin, anio-fabricacion: 75, peso: 2914, origen: 1
# modelo: pontiac astro, anio-fabricacion: 75, peso: 2592, origen: 1
# modelo: toyota corona, anio-fabricacion: 75, peso: 2702, origen: 3
# modelo: volkswagen dasher, anio-fabricacion: 75, peso: 2223, origen: 2
# modelo: datsun 710, anio-fabricacion: 75, peso: 2545, origen: 3
# modelo: ford pinto, anio-fabricacion: 75, peso: 2984, origen: 1
# modelo: volkswagen rabbit, anio-fabricacion: 75, peso: 1937, origen: 2
# modelo: amc pacer, anio-fabricacion: 75, peso: 3211, origen: 1
# modelo: audi 100ls, anio-fabricacion: 75, peso: 2694, origen: 2
# modelo: peugeot 504, anio-fabricacion: 75, peso: 2957, origen: 2
# modelo: volvo 244dl, anio-fabricacion: 75, peso: 2945, origen: 2
# modelo: saab 99le, anio-fabricacion: 75, peso: 2671, origen: 2
# modelo: honda civic cvcc, anio-fabricacion: 75, peso: 1795, origen: 3
# modelo: fiat 131, anio-fabricacion: 76, peso: 2464, origen: 2
# modelo: opel 1900, anio-fabricacion: 76, peso: 2220, origen: 2
# modelo: capri ii, anio-fabricacion: 76, peso: 2572, origen: 1
# modelo: dodge colt, anio-fabricacion: 76, peso: 2255, origen: 1
# modelo: renault 12tl, anio-fabricacion: 76, peso: 2202, origen: 2
# modelo: chevrolet chevelle malibu classic, anio-fabricacion: 76, peso: 4215, origen: 1
# modelo: dodge coronet brougham, anio-fabricacion: 76, peso: 4190, origen: 1
# modelo: amc matador, anio-fabricacion: 76, peso: 3962, origen: 1
# modelo: ford gran torino, anio-fabricacion: 76, peso: 4215, origen: 1
# modelo: plymouth valiant, anio-fabricacion: 76, peso: 3233, origen: 1
# modelo: chevrolet nova, anio-fabricacion: 76, peso: 3353, origen: 1
# modelo: ford maverick, anio-fabricacion: 76, peso: 3012, origen: 1
# modelo: amc hornet, anio-fabricacion: 76, peso: 3085, origen: 1
# modelo: chevrolet chevette, anio-fabricacion: 76, peso: 2035, origen: 1
# modelo: chevrolet woody, anio-fabricacion: 76, peso: 2164, origen: 1
# modelo: vw rabbit, anio-fabricacion: 76, peso: 1937, origen: 2
# modelo: honda civic, anio-fabricacion: 76, peso: 1795, origen: 3
# modelo: dodge aspen se, anio-fabricacion: 76, peso: 3651, origen: 1
# modelo: ford granada ghia, anio-fabricacion: 76, peso: 3574, origen: 1
# modelo: pontiac ventura sj, anio-fabricacion: 76, peso: 3645, origen: 1
# modelo: amc pacer d/l, anio-fabricacion: 76, peso: 3193, origen: 1
# modelo: volkswagen rabbit, anio-fabricacion: 76, peso: 1825, origen: 2
# modelo: datsun b-210, anio-fabricacion: 76, peso: 1990, origen: 3
# modelo: toyota corolla, anio-fabricacion: 76, peso: 2155, origen: 3
# modelo: ford pinto, anio-fabricacion: 76, peso: 2565, origen: 1
# modelo: volvo 245, anio-fabricacion: 76, peso: 3150, origen: 2
# modelo: plymouth volare premier v8, anio-fabricacion: 76, peso: 3940, origen: 1
# modelo: peugeot 504, anio-fabricacion: 76, peso: 3270, origen: 2
# modelo: toyota mark ii, anio-fabricacion: 76, peso: 2930, origen: 3
# modelo: mercedes-benz 280s, anio-fabricacion: 76, peso: 3820, origen: 2
# modelo: cadillac seville, anio-fabricacion: 76, peso: 4380, origen: 1
# modelo: chevy c10, anio-fabricacion: 76, peso: 4055, origen: 1
# modelo: ford f108, anio-fabricacion: 76, peso: 3870, origen: 1
# modelo: dodge d100, anio-fabricacion: 76, peso: 3755, origen: 1
# modelo: honda accord cvcc, anio-fabricacion: 77, peso: 2045, origen: 3
# modelo: buick opel isuzu deluxe, anio-fabricacion: 77, peso: 2155, origen: 1
# modelo: renault 5 gtl, anio-fabricacion: 77, peso: 1825, origen: 2
# modelo: plymouth arrow gs, anio-fabricacion: 77, peso: 2300, origen: 1
# modelo: datsun f-10 hatchback, anio-fabricacion: 77, peso: 1945, origen: 3
# modelo: chevrolet caprice classic, anio-fabricacion: 77, peso: 3880, origen: 1
# modelo: oldsmobile cutlass supreme, anio-fabricacion: 77, peso: 4060, origen: 1
# modelo: dodge monaco brougham, anio-fabricacion: 77, peso: 4140, origen: 1
# modelo: mercury cougar brougham, anio-fabricacion: 77, peso: 4295, origen: 1
# modelo: chevrolet concours, anio-fabricacion: 77, peso: 3520, origen: 1
# modelo: buick skylark, anio-fabricacion: 77, peso: 3425, origen: 1
# modelo: plymouth volare custom, anio-fabricacion: 77, peso: 3630, origen: 1
# modelo: ford granada, anio-fabricacion: 77, peso: 3525, origen: 1
# modelo: pontiac grand prix lj, anio-fabricacion: 77, peso: 4220, origen: 1
# modelo: chevrolet monte carlo landau, anio-fabricacion: 77, peso: 4165, origen: 1
# modelo: chrysler cordoba, anio-fabricacion: 77, peso: 4325, origen: 1
# modelo: ford thunderbird, anio-fabricacion: 77, peso: 4335, origen: 1
# modelo: volkswagen rabbit custom, anio-fabricacion: 77, peso: 1940, origen: 2
# modelo: pontiac sunbird coupe, anio-fabricacion: 77, peso: 2740, origen: 1
# modelo: toyota corolla liftback, anio-fabricacion: 77, peso: 2265, origen: 3
# modelo: ford mustang ii 2+2, anio-fabricacion: 77, peso: 2755, origen: 1
# modelo: chevrolet chevette, anio-fabricacion: 77, peso: 2051, origen: 1
# modelo: dodge colt m/m, anio-fabricacion: 77, peso: 2075, origen: 1
# modelo: subaru dl, anio-fabricacion: 77, peso: 1985, origen: 3
# modelo: volkswagen dasher, anio-fabricacion: 77, peso: 2190, origen: 2
# modelo: datsun 810, anio-fabricacion: 77, peso: 2815, origen: 3
# modelo: bmw 320i, anio-fabricacion: 77, peso: 2600, origen: 2
# modelo: mazda rx-4, anio-fabricacion: 77, peso: 2720, origen: 3
# modelo: volkswagen rabbit custom diesel, anio-fabricacion: 78, peso: 1985, origen: 2
# modelo: ford fiesta, anio-fabricacion: 78, peso: 1800, origen: 1
# modelo: mazda glc deluxe, anio-fabricacion: 78, peso: 1985, origen: 3
# modelo: datsun b210 gx, anio-fabricacion: 78, peso: 2070, origen: 3
# modelo: honda civic cvcc, anio-fabricacion: 78, peso: 1800, origen: 3
# modelo: oldsmobile cutlass salon brougham, anio-fabricacion: 78, peso: 3365, origen: 1
# modelo: dodge diplomat, anio-fabricacion: 78, peso: 3735, origen: 1
# modelo: mercury monarch ghia, anio-fabricacion: 78, peso: 3570, origen: 1
# modelo: pontiac phoenix lj, anio-fabricacion: 78, peso: 3535, origen: 1
# modelo: chevrolet malibu, anio-fabricacion: 78, peso: 3155, origen: 1
# modelo: ford fairmont (auto), anio-fabricacion: 78, peso: 2965, origen: 1
# modelo: ford fairmont (man), anio-fabricacion: 78, peso: 2720, origen: 1
# modelo: plymouth volare, anio-fabricacion: 78, peso: 3430, origen: 1
# modelo: amc concord, anio-fabricacion: 78, peso: 3210, origen: 1
# modelo: buick century special, anio-fabricacion: 78, peso: 3380, origen: 1
# modelo: mercury zephyr, anio-fabricacion: 78, peso: 3070, origen: 1
# modelo: dodge aspen, anio-fabricacion: 78, peso: 3620, origen: 1
# modelo: amc concord d/l, anio-fabricacion: 78, peso: 3410, origen: 1
# modelo: chevrolet monte carlo landau, anio-fabricacion: 78, peso: 3425, origen: 1
# modelo: buick regal sport coupe (turbo), anio-fabricacion: 78, peso: 3445, origen: 1
# modelo: ford futura, anio-fabricacion: 78, peso: 3205, origen: 1
# modelo: dodge magnum xe, anio-fabricacion: 78, peso: 4080, origen: 1
# modelo: chevrolet chevette, anio-fabricacion: 78, peso: 2155, origen: 1
# modelo: toyota corona, anio-fabricacion: 78, peso: 2560, origen: 3
# modelo: datsun 510, anio-fabricacion: 78, peso: 2300, origen: 3
# modelo: dodge omni, anio-fabricacion: 78, peso: 2230, origen: 1
# modelo: toyota celica gt liftback, anio-fabricacion: 78, peso: 2515, origen: 3
# modelo: plymouth sapporo, anio-fabricacion: 78, peso: 2745, origen: 1
# modelo: oldsmobile starfire sx, anio-fabricacion: 78, peso: 2855, origen: 1
# modelo: datsun 200-sx, anio-fabricacion: 78, peso: 2405, origen: 3
# modelo: audi 5000, anio-fabricacion: 78, peso: 2830, origen: 2
# modelo: volvo 264gl, anio-fabricacion: 78, peso: 3140, origen: 2
# modelo: saab 99gle, anio-fabricacion: 78, peso: 2795, origen: 2
# modelo: peugeot 604sl, anio-fabricacion: 78, peso: 3410, origen: 2
# modelo: volkswagen scirocco, anio-fabricacion: 78, peso: 1990, origen: 2
# modelo: honda accord lx, anio-fabricacion: 78, peso: 2135, origen: 3
# modelo: pontiac lemans v6, anio-fabricacion: 79, peso: 3245, origen: 1
# modelo: mercury zephyr 6, anio-fabricacion: 79, peso: 2990, origen: 1
# modelo: ford fairmont 4, anio-fabricacion: 79, peso: 2890, origen: 1
# modelo: amc concord dl 6, anio-fabricacion: 79, peso: 3265, origen: 1
# modelo: dodge aspen 6, anio-fabricacion: 79, peso: 3360, origen: 1
# modelo: chevrolet caprice classic, anio-fabricacion: 79, peso: 3840, origen: 1
# modelo: ford ltd landau, anio-fabricacion: 79, peso: 3725, origen: 1
# modelo: mercury grand marquis, anio-fabricacion: 79, peso: 3955, origen: 1
# modelo: dodge st. regis, anio-fabricacion: 79, peso: 3830, origen: 1
# modelo: buick estate wagon (sw), anio-fabricacion: 79, peso: 4360, origen: 1
# modelo: ford country squire (sw), anio-fabricacion: 79, peso: 4054, origen: 1
# modelo: chevrolet malibu classic (sw), anio-fabricacion: 79, peso: 3605, origen: 1
# modelo: chrysler lebaron town @ country (sw), anio-fabricacion: 79, peso: 3940, origen: 1
# modelo: vw rabbit custom, anio-fabricacion: 79, peso: 1925, origen: 2
# modelo: maxda glc deluxe, anio-fabricacion: 79, peso: 1975, origen: 3
# modelo: dodge colt hatchback custom, anio-fabricacion: 79, peso: 1915, origen: 1
# modelo: amc spirit dl, anio-fabricacion: 79, peso: 2670, origen: 1
# modelo: mercedes benz 300d, anio-fabricacion: 79, peso: 3530, origen: 2
# modelo: cadillac eldorado, anio-fabricacion: 79, peso: 3900, origen: 1
# modelo: peugeot 504, anio-fabricacion: 79, peso: 3190, origen: 2
# modelo: oldsmobile cutlass salon brougham, anio-fabricacion: 79, peso: 3420, origen: 1
# modelo: plymouth horizon, anio-fabricacion: 79, peso: 2200, origen: 1
# modelo: plymouth horizon tc3, anio-fabricacion: 79, peso: 2150, origen: 1
# modelo: datsun 210, anio-fabricacion: 79, peso: 2020, origen: 3
# modelo: fiat strada custom, anio-fabricacion: 79, peso: 2130, origen: 2
# modelo: buick skylark limited, anio-fabricacion: 79, peso: 2670, origen: 1
# modelo: chevrolet citation, anio-fabricacion: 79, peso: 2595, origen: 1
# modelo: oldsmobile omega brougham, anio-fabricacion: 79, peso: 2700, origen: 1
# modelo: pontiac phoenix, anio-fabricacion: 79, peso: 2556, origen: 1
# modelo: vw rabbit, anio-fabricacion: 80, peso: 2144, origen: 2
# modelo: toyota corolla tercel, anio-fabricacion: 80, peso: 1968, origen: 3
# modelo: chevrolet chevette, anio-fabricacion: 80, peso: 2120, origen: 1
# modelo: datsun 310, anio-fabricacion: 80, peso: 2019, origen: 3
# modelo: chevrolet citation, anio-fabricacion: 80, peso: 2678, origen: 1
# modelo: ford fairmont, anio-fabricacion: 80, peso: 2870, origen: 1
# modelo: amc concord, anio-fabricacion: 80, peso: 3003, origen: 1
# modelo: dodge aspen, anio-fabricacion: 80, peso: 3381, origen: 1
# modelo: audi 4000, anio-fabricacion: 80, peso: 2188, origen: 2
# modelo: toyota corona liftback, anio-fabricacion: 80, peso: 2711, origen: 3
# modelo: mazda 626, anio-fabricacion: 80, peso: 2542, origen: 3
# modelo: datsun 510 hatchback, anio-fabricacion: 80, peso: 2434, origen: 3
# modelo: toyota corolla, anio-fabricacion: 80, peso: 2265, origen: 3
# modelo: mazda glc, anio-fabricacion: 80, peso: 2110, origen: 3
# modelo: dodge colt, anio-fabricacion: 80, peso: 2800, origen: 1
# modelo: datsun 210, anio-fabricacion: 80, peso: 2110, origen: 3
# modelo: vw rabbit c (diesel), anio-fabricacion: 80, peso: 2085, origen: 2
# modelo: vw dasher (diesel), anio-fabricacion: 80, peso: 2335, origen: 2
# modelo: audi 5000s (diesel), anio-fabricacion: 80, peso: 2950, origen: 2
# modelo: mercedes-benz 240d, anio-fabricacion: 80, peso: 3250, origen: 2
# modelo: honda civic 1500 gl, anio-fabricacion: 80, peso: 1850, origen: 3
# modelo: renault lecar deluxe, anio-fabricacion: 80, peso: 1835, origen: 2
# modelo: subaru dl, anio-fabricacion: 80, peso: 2145, origen: 3
# modelo: vokswagen rabbit, anio-fabricacion: 80, peso: 1845, origen: 2
# modelo: datsun 280-zx, anio-fabricacion: 80, peso: 2910, origen: 3
# modelo: mazda rx-7 gs, anio-fabricacion: 80, peso: 2420, origen: 3
# modelo: triumph tr7 coupe, anio-fabricacion: 80, peso: 2500, origen: 2
# modelo: ford mustang cobra, anio-fabricacion: 80, peso: 2905, origen: 1
# modelo: honda accord, anio-fabricacion: 80, peso: 2290, origen: 3
# modelo: plymouth reliant, anio-fabricacion: 81, peso: 2490, origen: 1
# modelo: buick skylark, anio-fabricacion: 81, peso: 2635, origen: 1
# modelo: dodge aries wagon (sw), anio-fabricacion: 81, peso: 2620, origen: 1
# modelo: chevrolet citation, anio-fabricacion: 81, peso: 2725, origen: 1
# modelo: plymouth reliant, anio-fabricacion: 81, peso: 2385, origen: 1
# modelo: toyota starlet, anio-fabricacion: 81, peso: 1755, origen: 3
# modelo: plymouth champ, anio-fabricacion: 81, peso: 1875, origen: 1
# modelo: honda civic 1300, anio-fabricacion: 81, peso: 1760, origen: 3
# modelo: subaru, anio-fabricacion: 81, peso: 2065, origen: 3
# modelo: datsun 210 mpg, anio-fabricacion: 81, peso: 1975, origen: 3
# modelo: toyota tercel, anio-fabricacion: 81, peso: 2050, origen: 3
# modelo: mazda glc 4, anio-fabricacion: 81, peso: 1985, origen: 3
# modelo: plymouth horizon 4, anio-fabricacion: 81, peso: 2215, origen: 1
# modelo: ford escort 4w, anio-fabricacion: 81, peso: 2045, origen: 1
# modelo: ford escort 2h, anio-fabricacion: 81, peso: 2380, origen: 1
# modelo: volkswagen jetta, anio-fabricacion: 81, peso: 2190, origen: 2
# modelo: renault 18i, anio-fabricacion: 81, peso: 2320, origen: 2
# modelo: honda prelude, anio-fabricacion: 81, peso: 2210, origen: 3
# modelo: toyota corolla, anio-fabricacion: 81, peso: 2350, origen: 3
# modelo: datsun 200sx, anio-fabricacion: 81, peso: 2615, origen: 3
# modelo: mazda 626, anio-fabricacion: 81, peso: 2635, origen: 3
# modelo: peugeot 505s turbo diesel, anio-fabricacion: 81, peso: 3230, origen: 2
# modelo: saab 900s, anio-fabricacion: 81, peso: 2800, origen: 2
# modelo: volvo diesel, anio-fabricacion: 81, peso: 3160, origen: 2
# modelo: toyota cressida, anio-fabricacion: 81, peso: 2900, origen: 3
# modelo: datsun 810 maxima, anio-fabricacion: 81, peso: 2930, origen: 3
# modelo: buick century, anio-fabricacion: 81, peso: 3415, origen: 1
# modelo: oldsmobile cutlass ls, anio-fabricacion: 81, peso: 3725, origen: 1
# modelo: ford granada gl, anio-fabricacion: 81, peso: 3060, origen: 1
# modelo: chrysler lebaron salon, anio-fabricacion: 81, peso: 3465, origen: 1
# modelo: chevrolet cavalier, anio-fabricacion: 82, peso: 2605, origen: 1
# modelo: chevrolet cavalier wagon, anio-fabricacion: 82, peso: 2640, origen: 1
# modelo: chevrolet cavalier 2-door, anio-fabricacion: 82, peso: 2395, origen: 1
# modelo: pontiac j2000 se hatchback, anio-fabricacion: 82, peso: 2575, origen: 1
# modelo: dodge aries se, anio-fabricacion: 82, peso: 2525, origen: 1
# modelo: pontiac phoenix, anio-fabricacion: 82, peso: 2735, origen: 1
# modelo: ford fairmont futura, anio-fabricacion: 82, peso: 2865, origen: 1
# modelo: amc concord dl, anio-fabricacion: 82, peso: 3035, origen: 1
# modelo: volkswagen rabbit l, anio-fabricacion: 82, peso: 1980, origen: 2
# modelo: mazda glc custom l, anio-fabricacion: 82, peso: 2025, origen: 3
# modelo: mazda glc custom, anio-fabricacion: 82, peso: 1970, origen: 3
# modelo: plymouth horizon miser, anio-fabricacion: 82, peso: 2125, origen: 1
# modelo: mercury lynx l, anio-fabricacion: 82, peso: 2125, origen: 1
# modelo: nissan stanza xe, anio-fabricacion: 82, peso: 2160, origen: 3
# modelo: honda accord, anio-fabricacion: 82, peso: 2205, origen: 3
# modelo: toyota corolla, anio-fabricacion: 82, peso: 2245, origen: 3
# modelo: honda civic, anio-fabricacion: 82, peso: 1965, origen: 3
# modelo: honda civic (auto), anio-fabricacion: 82, peso: 1965, origen: 3
# modelo: datsun 310 gx, anio-fabricacion: 82, peso: 1995, origen: 3
# modelo: buick century limited, anio-fabricacion: 82, peso: 2945, origen: 1
# modelo: oldsmobile cutlass ciera (diesel), anio-fabricacion: 82, peso: 3015, origen: 1
# modelo: chrysler lebaron medallion, anio-fabricacion: 82, peso: 2585, origen: 1
# modelo: ford granada l, anio-fabricacion: 82, peso: 2835, origen: 1
# modelo: toyota celica gt, anio-fabricacion: 82, peso: 2665, origen: 3
# modelo: dodge charger 2.2, anio-fabricacion: 82, peso: 2370, origen: 1
# modelo: chevrolet camaro, anio-fabricacion: 82, peso: 2950, origen: 1
# modelo: ford mustang gl, anio-fabricacion: 82, peso: 2790, origen: 1
# modelo: vw pickup, anio-fabricacion: 82, peso: 2130, origen: 2
# modelo: dodge rampage, anio-fabricacion: 82, peso: 2295, origen: 1
# modelo: ford ranger, anio-fabricacion: 82, peso: 2625, origen: 1
# modelo: chevy s-10, anio-fabricacion: 82, peso: 2720, origen: 1
